# %%
import pandas as pd
import nltk
#nltk.download('punkt')
#nltk.download('wordnet')
from nltk import sent_tokenize, word_tokenize
df1 = pd.read_pickle("LRrefined.pkl")

# %%
##import all the packages
from sklearn.feature_selection import SelectPercentile
from sklearn.feature_selection import f_classif
#from sklearn.linear_model import SGDClassifier
#from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import f_regression
import numpy as np

# %%
#Using TFIDF
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(max_df=0.90, min_df=2)
# TF-IDF feature matrix
tfidf = tfidf_vectorizer.fit_transform(df1['tweets'])
y=df1.label

# %%
tfidf.shape
X=df1.tweets

# %%
#Spliting the data
from sklearn.model_selection import train_test_split  
X_train, X_test, y_train, y_test = train_test_split(tfidf, y, test_size=0.2, random_state=42)

# %%
X_transformed = tfidf_vectorizer.fit_transform(X)

# %%
X_transformed.shape
# Out:
# (1900, 224552)

# %%
#choosing the best 100 features from 1000
from sklearn.model_selection import GridSearchCV

selector = SelectPercentile(f_classif, percentile = 10)  ##here we get the 10%best features
selector.fit(X_transformed, y)
# Out:
# SelectPercentile(percentile=10,
#                  score_func=<function f_classif at 0x000002242E4B2158>)

# %%
X_best = selector.transform(X_transformed).toarray()

# %%
X_best.shape
#we now have 100 features
# Out:
# (1900, 22456)

# %%
#spliting into train and test data
X_best_train, X_best_test,labels_train,labels_test = train_test_split(X_best,y, test_size = 0.3, random_state = 40)

# %%
import warnings
warnings.filterwarnings('ignore')
#import numpy as np
#import pandas as pd
#from datetime import datetime
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold
#from xgboost import XGBClassifier

# %%
from xgboost import XGBClassifier
params={
        'min_child_weight': [1, 5, 10],
        'gamma': [0.5, 1, 1.5, 2, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [3, 4, 5]
        }
xgb=XGBClassifier()

print("tuned hpyerparameters :(best parameters) ",xgb_cv.best_params_)
folds = 3
param_comb = 5

skf = StratifiedKFold(n_splits=folds, shuffle = True, random_state = 1001)

random_search = RandomizedSearchCV(xgb, param_distributions=params, n_iter=param_comb, scoring='roc_auc', n_jobs=4, cv=skf.split(X_best,y), verbose=3, random_state=1001 )
random_search.fit(X_best, y)
print('\n Best hyperparameters:')
print(random_search.best_params_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-5ef745978fd9> in <module>
#       9 xgb=XGBClassifier()
#      10 #xgb_cv=GridSearchCV(xgb,params,cv=10)
# ---> 11 xgb_cv = GridSearchCV(estimator=xgb, param_grid=params, scoring='roc_auc', n_jobs=4, cv=skf.split(X_best,y), verbose=3 )
#      12 xgb.fit(X_best,y)
#      13 print("tuned hpyerparameters :(best parameters) ",xgb_cv.best_params_)
#
# NameError: name 'skf' is not defined

# %%
model = XGBClassifier(learning_rate=0.02, n_estimators=600, objective='binary:logistic',
                    silent=True, nthread=1, subsample= 0.8, min_child_weight= 1, max_depth=4, gamma= 1, colsample_bytree= 1.0)
model.fit(X_best_train, labels_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1.0, gamma=1,
#               learning_rate=0.02, max_delta_step=0, max_depth=4,
#               min_child_weight=1, missing=None, n_estimators=600, n_jobs=1,
#               nthread=1, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=True, subsample=0.8, verbosity=1)

# %%
predictions = model.predict(X_best_test)
 
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
 
print(confusion_matrix(labels_test,predictions)) 
print(classification_report(labels_test,predictions))  
print(accuracy_score(labels_test, predictions))
# Out:
# [[282   2]
#  [ 12 274]]
#               precision    recall  f1-score   support
#
#         Left       0.96      0.99      0.98       284
#        Right       0.99      0.96      0.98       286
#
#     accuracy                           0.98       570
#    macro avg       0.98      0.98      0.98       570
# weighted avg       0.98      0.98      0.98       570
#
# 0.9754385964912281

# %%
#import the M5 pickle file
df_M5 = pd.read_pickle("RefinedM5.pkl")

# %%
#TFIDF for M5 followers
#Using TFIDF vectorizers
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(max_df=0.90, min_df=2,max_features=44911)
# TF-IDF feature matrix
tfidf = tfidf_vectorizer.fit_transform(df_M5['tweets'])

# %%
tfidf.shape
X=df_M5.tweets

# %%
#Transorm into TFIDF values
M5X_transformed = tfidf_vectorizer.fit_transform(X)

# %%
M5X_transformed.shape
# Out:
# (649, 44911)

# %%
M5_y_predict = model.predict(M5X_transformed)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-e2a13f9a1e49> in <module>
# ----> 1 M5_y_predict = model.predict(M5X_transformed)
#
# ~\Anaconda3\lib\site-packages\xgboost\sklearn.py in predict(self, data, output_margin, ntree_limit, validate_features)
#     789                                                  output_margin=output_margin,
#     790                                                  ntree_limit=ntree_limit,
# --> 791                                                  validate_features=validate_features)
#     792         if output_margin:
#     793             # If output_margin is active, simply return the scores
#
# ~\Anaconda3\lib\site-packages\xgboost\core.py in predict(self, data, output_margin, ntree_limit, pred_leaf, pred_contribs, approx_contribs, pred_interactions, validate_features)
#    1282
#    1283         if validate_features:
# ...

# %%
len(M5_y_predict)

# %%
import collections, numpy
collections.Counter(M5_y_predict)

# %%
#Using Bag of Words

from sklearn.feature_extraction.text import CountVectorizer
bow_vectorizer = CountVectorizer(max_df=0.90, min_df=2, max_features=1000)
# bag-of-words feature matrix
bow = bow_vectorizer.fit_transform(df1['tweets'])

# %%
from sklearn.model_selection import train_test_split  
X_train, X_test, y_train, y_test = train_test_split(bow, y, test_size=0.2, random_state=42)

# %%
# fit model no training data
model = XGBClassifier(learning_rate=0.02, n_estimators=600, objective='binary:logistic',
                    silent=True, nthread=1, subsample= 0.8, min_child_weight= 1, max_depth=4, gamma= 1, colsample_bytree= 1.0)
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1.0, gamma=1,
#               learning_rate=0.02, max_delta_step=0, max_depth=4,
#               min_child_weight=1, missing=None, n_estimators=600, n_jobs=1,
#               nthread=1, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=True, subsample=0.8, verbosity=1)

# %%
predictions = model.predict(X_test)
 
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test,predictions)) 
print(classification_report(y_test,predictions))  
print(accuracy_score(y_test, predictions))
# Out:
# [[30 28]
#  [39 23]]
#               precision    recall  f1-score   support
#
#         Left       0.43      0.52      0.47        58
#        Right       0.45      0.37      0.41        62
#
#     accuracy                           0.44       120
#    macro avg       0.44      0.44      0.44       120
# weighted avg       0.44      0.44      0.44       120
#
# 0.44166666666666665

# %% [markdown]
#             The TFIDF APPROACH GIVES A HIGHER ACCURACY (RELATIVELY SPEAKING ) OF 53%
